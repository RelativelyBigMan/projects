# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression

# %%
sample_data = pd.read_excel("Sun-Dried Sample Data.xlsx", sheet_name="Sheet1")
sample_data.columns
# Out:
# Index(['Temperature (C)', 'Pressure (hPa)', 'Humidity (%)', 'Longitude',
#        'Latitude', 'Wind Speed (km/h)', 'Clothing Type', 'Weight (kg)',
#        'Start-Time', 'Fabric', 'Drying Time'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# Split data into features and label 
X = sample_data.drop(["Clothing Type","Fabric", "Start-Time"], axis=1).copy()
y = sample_data["Drying Time"].copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# Instantiate scaler and fit on features
#enc = OneHotEncoder()
#enc.fit(X["Clothing Type","Fabric"].values)
#X_enc = enc.transform(X["Clothing Type","Fabric"].values)
#print(X_enc)

scaler = StandardScaler()
scaler.fit(X_train.values)
X_train = scaler.transform(X_train.values)
X_test = scaler.transform(X_test.values)

# View first instance
#print(X.columns)

#y = X_scaled[-1]
#print(y)

# %%
lr = LogisticRegression().fit(X_train, y_train)
plt.scatter(lr.predict(X_test), y_test)
plt.show()
